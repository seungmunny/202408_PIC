# %%
# !pip install yellowbrick
# !pip install numpy==1.22.4
# !pip install -U matplotlib==3.8.2
# !pip install pandas
# !pip install pyarrow
# !pip install seaborn
# !pip install tensorflow==2.13.1
# !pip install scikit-learn
# Out:
# Collecting yellowbrick
#   Using cached yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Collecting matplotlib!=3.0.0,>=2.0.2 (from yellowbrick)
#   Using cached matplotlib-3.9.2-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting scipy>=1.0.0 (from yellowbrick)
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Collecting scikit-learn>=1.0.0 (from yellowbrick)
#   Using cached scikit_learn-1.5.1-cp39-cp39-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from yellowbrick) (2.0.1)
# Collecting cycler>=0.10.0 (from yellowbrick)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.0.0,>=2.0.2->yellowbrick)
#   Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl.metadata (5.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.0.0,>=2.0.2->yellowbrick)
#   Using cached fonttools-4.53.1-cp39-cp39-win_amd64.whl.metadata (165 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.0.0,>=2.0.2->yellowbrick)
#   Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.4.0)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.0.0,>=2.0.2->yellowbrick)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib!=3.0.0,>=2.0.2->yellowbrick)
#   Downloading importlib_resources-6.4.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting joblib>=1.2.0 (from scikit-learn>=1.0.0->yellowbrick)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.0.0->yellowbrick)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached matplotlib-3.9.2-cp39-cp39-win_amd64.whl (7.8 MB)
# Using cached scikit_learn-1.5.1-cp39-cp39-win_amd64.whl (11.0 MB)
# Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
# Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl (182 kB)
# Using cached fonttools-4.53.1-cp39-cp39-win_amd64.whl (2.2 MB)
# Downloading importlib_resources-6.4.3-py3-none-any.whl (35 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached kiwisolver-1.4.5-cp39-cp39-win_amd64.whl (56 kB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, pyparsing, kiwisolver, joblib, importlib-resources, fonttools, cycler, contourpy, scikit-learn, matplotlib, yellowbrick
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.53.1 importlib-resources-6.4.3 joblib-1.4.2 kiwisolver-1.4.5 matplotlib-3.9.2 pyparsing-3.1.2 scikit-learn-1.5.1 scipy-1.13.1 threadpoolctl-3.5.0 yellowbrick-1.5
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# Collecting numpy==1.22.4
#   Using cached numpy-1.22.4-cp39-cp39-win_amd64.whl.metadata (2.1 kB)
# Using cached numpy-1.22.4-cp39-cp39-win_amd64.whl (14.7 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.1
#     Uninstalling numpy-2.0.1:
#       Successfully uninstalled numpy-2.0.1
# Successfully installed numpy-1.22.4
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.12.2 requires gast>=0.3.2, which is not installed.
# matplotlib 3.9.2 requires numpy>=1.23, but you have numpy 1.22.4 which is incompatible.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# Collecting matplotlib==3.8.2
#   Using cached matplotlib-3.8.2-cp39-cp39-win_amd64.whl.metadata (5.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib==3.8.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib==3.8.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib==3.8.2) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib==3.8.2) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib==3.8.2) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib==3.8.2) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib==3.8.2) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib==3.8.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib==3.8.2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib==3.8.2) (6.4.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib==3.8.2) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib==3.8.2) (1.16.0)
# Using cached matplotlib-3.8.2-cp39-cp39-win_amd64.whl (7.6 MB)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.9.2
#     Uninstalling matplotlib-3.9.2:
#       Successfully uninstalled matplotlib-3.9.2
# Successfully installed matplotlib-3.8.2
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# Collecting pandas
#   Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from pandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python39\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp39-cp39-win_amd64.whl (11.6 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# Collecting pyarrow
#   Using cached pyarrow-17.0.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from pyarrow) (1.22.4)
# Using cached pyarrow-17.0.0-cp39-cp39-win_amd64.whl (25.1 MB)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-17.0.0
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from seaborn) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python39\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# Collecting tensorflow==2.13.1
#   Using cached tensorflow-2.13.1-cp39-cp39-win_amd64.whl.metadata (2.6 kB)
# Collecting tensorflow-intel==2.13.1 (from tensorflow==2.13.1)
#   Using cached tensorflow_intel-2.13.1-cp39-cp39-win_amd64.whl.metadata (4.1 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=23.1.21 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached gast-0.4.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=2.9.0 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached h5py-3.11.0-cp39-cp39-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.1) (1.22.4)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.1) (24.1)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached protobuf-4.25.4-cp39-cp39-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.1) (72.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.1) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from tensorflow-intel==2.13.1->tensorflow==2.13.1) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Downloading grpcio-1.65.5-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Collecting tensorboard<2.14,>=2.13 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached tensorboard-2.13.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorflow-estimator<2.14,>=2.13.0 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting keras<2.14,>=2.13.1 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached keras-2.13.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.13.1->tensorflow==2.13.1) (0.44.0)
# Collecting google-auth<3,>=1.6.3 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached google_auth-2.33.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1) (2.32.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached cachetools-5.4.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\user\appdata\roaming\python\python39\site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1) (8.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1) (3.19.2)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow-intel==2.13.1->tensorflow==2.13.1)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Using cached tensorflow-2.13.1-cp39-cp39-win_amd64.whl (1.9 kB)
# Using cached tensorflow_intel-2.13.1-cp39-cp39-win_amd64.whl (276.5 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.65.5-cp39-cp39-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/4.1 MB 5.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.4/4.1 MB 5.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.7/4.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 6.1 MB/s eta 0:00:00
# Using cached h5py-3.11.0-cp39-cp39-win_amd64.whl (3.0 MB)
# Using cached keras-2.13.1-py3-none-any.whl (1.7 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Using cached protobuf-4.25.4-cp39-cp39-win_amd64.whl (413 kB)
# Using cached tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
# Using cached tensorflow_estimator-2.13.0-py2.py3-none-any.whl (440 kB)
# Using cached tensorflow_io_gcs_filesystem-0.31.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Using cached termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Using cached google_auth-2.33.0-py2.py3-none-any.whl (200 kB)
# Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Using cached cachetools-5.4.0-py3-none-any.whl (9.5 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Installing collected packages: libclang, flatbuffers, werkzeug, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, opt-einsum, oauthlib, keras, h5py, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, rsa, requests-oauthlib, pyasn1-modules, markdown, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 cachetools-5.4.0 flatbuffers-24.3.25 gast-0.4.0 google-auth-2.33.0 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.65.5 h5py-3.11.0 keras-2.13.1 libclang-18.1.1 markdown-3.7 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.25.4 pyasn1-0.6.0 pyasn1-modules-0.4.0 requests-oauthlib-2.0.0 rsa-4.9 tensorboard-2.13.0 tensorboard-data-server-0.7.2 tensorflow-2.13.1 tensorflow-estimator-2.13.0 tensorflow-intel-2.13.1 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0 typing-extensions-4.5.0 werkzeug-3.0.3
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.1.1 requires fsspec, which is not installed.
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# Requirement already satisfied: scikit-learn in c:\users\user\miniforge3\envs\picenv\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\miniforge3\envs\picenv\lib\site-packages (from scikit-learn) (3.5.0)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\user\appdata\roaming\python\python39\site-packages)

# %% [markdown]
# 데이터 로드

# %%
import pandas as pd
df = pd.read_csv("dataset/Mall_Customers.csv")
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# 데이터 전처리

# %%
from sklearn.preprocessing import MinMaxScaler

# 두 가지 feature를 대상
data = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# 정규화 진행
scaler = MinMaxScaler()
data_scale = scaler.fit_transform(data)

# %%
print(data_scale[:10])
# Out:
# [[0.         0.3877551 ]
#  [0.         0.81632653]
#  [0.00819672 0.05102041]
#  [0.00819672 0.7755102 ]
#  [0.01639344 0.39795918]
#  [0.01639344 0.76530612]
#  [0.02459016 0.05102041]
#  [0.02459016 0.94897959]
#  [0.03278689 0.02040816]
#  [0.03278689 0.7244898 ]]

# %% [markdown]
# 모델 불러오기

# %%
from sklearn.cluster import KMeans

k = 4

# 그룹 수, random_state 설정
model = KMeans(n_clusters = k, random_state = 10)

# 정규화된 데이터에 학습
model.fit(data_scale)

# 클러스터링 결과 각 데이터가 몇 번째 그룹에 속하는지 저장
df['cluster'] = model.fit_predict(data_scale)

# %% [markdown]
# 결과 확인

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (8, 8))

for i in range(k):
    plt.scatter(df.loc[df['cluster'] == i, 'Annual Income (k$)'], df.loc[df['cluster'] == i, 'Spending Score (1-100)'],
                label = 'cluster ' + str(i))

plt.legend()
plt.title('K = %d results'%k , size = 15)
plt.xlabel('Annual Income', size = 12)
plt.ylabel('Spending Score', size = 12)
plt.show()

# %% [markdown]
# 최적 K값 탐색

# %%
from yellowbrick.cluster import KElbowVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,10))
visualizer.fit(data_scale)
# 파란색-각 데이터들의 군중 중심과의 평균 거리
# 초록색-학습 시간
# Out:
# KElbowVisualizer(ax=<Axes: >, estimator=KMeans(n_clusters=9), k=(1, 10))
